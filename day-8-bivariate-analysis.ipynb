# %% [markdown]
# # 🔥 Day-8: Bivariate Analysis
#
# ---
#
# ## 🌟 What is Bivariate Analysis?
#
# **Bivariate Analysis** is the process of exploring the relationship between **two variables** in a dataset.
# It helps to:
# - Understand how one variable influences or is related to another
# - Identify correlations and patterns
#
# ---
#
# ## 🧩 Techniques of Bivariate Analysis
#
# ### 🔸 For **Numerical vs Numerical**
# 1. **Scatter Plot**
# 2. **Correlation Coefficient**
# 3. **Heatmap**
#
# ### 🔸 For **Categorical vs Numerical**
# 1. **Box Plot**
# 2. **Violin Plot**
# 3. **Bar Plot (Grouped)**
#
# ### 🔸 For **Categorical vs Categorical**
# 1. **Crosstab**
# 2. **Stacked Bar Plot**
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#numerical vs category 
sns.scatterplot(x=df['age'],y=df['fare'])
plt.show()

# %%
#category vs numerical
sns.boxplot(x=df['pclass'],y=df['fare'])
plt.show()

# %%
#category vs category 
sns.countplot(x=df['sex'],hue=df['survived'])
plt.show()

# %%
#numerical vs numerical
numerical_cols = df.select_dtypes(include=['int64','float64']).columns
corr = df[numerical_cols].corr()
plt.figure(figsize=(8,5))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %%
#category vs numerical
sns.violinplot(x=df['pclass'],y=df['age'])
plt.show()

# %%
sns.kdeplot(df[df['survived'] == 1]['fare'], label="Survived", shade=True)
sns.kdeplot(df[df['survived'] == 0]['fare'], label="Not Survived", shade=True)
plt.legend()
plt.show()
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_13332\2063816637.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['survived'] == 1]['fare'], label="Survived", shade=True)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_13332\2063816637.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['survived'] == 0]['fare'], label="Not Survived", shade=True)
